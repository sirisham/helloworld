# %%
import sys

print(sys.version)
print(sys.version_info)
# Out:
# 3.8.8 (default, Apr 13 2021, 12:59:45)
# [Clang 10.0.0 ]
# sys.version_info(major=3, minor=8, micro=8, releaselevel='final', serial=0)

# %%
import pandas as pd

#LOads the survey file
df = pd.read_csv("/Users/sirisha/Desktop/Pandas_demo/data/survey_results_public.csv", index_col = 'ResponseId')

#Loads the schema file
schema_df = pd.read_csv("/Users/sirisha/Desktop/Pandas_demo/data/survey_results_schema.csv")


#Rows * Columns
df.shape

#Verify the Dtype and column details
df.info()
df.dtypes
#df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83439 entries, 1 to 83439
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    83439 non-null  object
#  1   Employment                    83323 non-null  object
#  2   Country                       83439 non-null  object
#  3   US_State                      14920 non-null  object
#  4   UK_Country                    4418 non-null   object
#  5   EdLevel                       83126 non-null  object
#  6   Age1stCode                    83243 non-null  object
#  7   LearnCode                     82963 non-null  object
#  8   YearsCode                     81641 non-null  object
#  9   YearsCodePro                  61216 non-null  object
#  10  DevType                       66484 non-null  object
#  11  OrgSize                       60726 non-null  object
# ...

# %%
#ALter the no of column display
pd.set_option('display.max_columns',45)

#Sorting by index
df.sort_index(inplace = True)


# to get the consolidated data on a paticular column 
df['SurveyEase'].value_counts()
# Out:
# Easy                          63087
# Neither easy nor difficult    18091
# Difficult                       770
# Name: SurveyEase, dtype: int64

# %%
# Displays the list of columns
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.loc[0:5,'DevType':'CompFreq']
# Out:
#                                                       DevType  \
# ResponseId
# 1                                           Developer, mobile
# 2                                                         NaN
# 3                                                         NaN
# 4                                        Developer, front-end
# 5           Developer, desktop or enterprise applications;...
#
#                                                       OrgSize  \
# ResponseId
# 1                                          20 to 99 employees
# 2                                                         NaN
# 3                                                         NaN
# 4                                        100 to 499 employees
# 5           Just me - I am a freelancer, sole proprietor, ...
#
#                        Currency  CompTotal CompFreq
# ResponseId
# 1             EUR European Euro     4800.0  Monthly
# 2                           NaN        NaN      NaN
# ...

# %%
schema_df.columns


df['NEWCollabToolsHaveWorkedWith'].value_counts()
# Out:
# Visual Studio Code                                                                                      6700
# Visual Studio;Visual Studio Code                                                                        3357
# Notepad++;Visual Studio;Visual Studio Code                                                              2382
# Vim;Visual Studio Code                                                                                  1527
# IntelliJ;Visual Studio Code                                                                             1378
#                                                                                                         ...
# Eclipse;IntelliJ;Rider;Sublime Text;Vim;Xcode                                                              1
# Atom;IPython/Jupyter;Notepad++;Sublime Text;Vim;Visual Studio;Visual Studio Code                           1
# Android Studio;Eclipse;IntelliJ;Notepad++;PHPStorm;PyCharm;Rider;Sublime Text;Visual Studio;Webstorm       1
# ...

# %%
countries  = ['Canada','India']

filt = df['Country'].isin(countries)

# df.loc[filt,'DevType'].str.contains('Developer', na = False)

df[filt]
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 9                   I am a developer by profession  Employed part-time
# 18                  I am a developer by profession  Employed full-time
# 23          I am a student who is learning to code  Student, full-time
# 40          I am a student who is learning to code  Student, part-time
# 50          I am a student who is learning to code  Student, full-time
# ...                                            ...                 ...
# 83411       I am a student who is learning to code  Student, part-time
# 83412               I am a developer by profession  Employed full-time
# 83418               I am a developer by profession  Student, full-time
# 83433               I am a developer by profession  Employed full-time
# 83438               I am a developer by profession  Employed full-time
#
#            Country US_State UK_Country  \
# ResponseId
# 9            India      NaN        NaN
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.columns = [x.upper() for x in df.columns]
df
df.rename(columns= {'DEVTYPE':'dev'}, inplace = True)

df
# Out:
#                                                    MAINBRANCH  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    EMPLOYMENT  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
filt = (df['CompTotal'] > 5000) & (df['CompFreq'] == 'Monthly')

df.loc[filt,['Country','DevType','CompFreq','CompTotal']]
# Out:
#                        Country  \
# ResponseId
# 10                      Sweden
# 17                      Turkey
# 19                   Singapore
# 30          Russian Federation
# 32                      Israel
# ...                        ...
# 83429                   Brazil
# 83432                 Pakistan
# 83436                    Benin
# 83438                   Canada
# 83439                   Brazil
#
#                                                       DevType CompFreq  \
# ResponseId
# 10              Data scientist or machine learning specialist  Monthly
# 17                                      Developer, full-stack  Monthly
# 19                                                        NaN  Monthly
# 30          Developer, desktop or enterprise applications;...  Monthly
# 32                         Engineer, data;Developer, back-end  Monthly
# ...                                                       ...      ...
# ...
